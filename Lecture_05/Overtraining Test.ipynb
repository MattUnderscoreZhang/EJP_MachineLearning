# %% [markdown]
# # A Full Analysis

# %% [markdown]
# In this exercise we will try to predict the price of wine given various information. This data is taken from Kaggle at https://www.kaggle.com/zynicide/wine-reviews/data, and originally scraped from WineEnthusiast.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(open('Files/wine.csv'))
data
# Out:
#         Unnamed: 0      country  \
# 0                0        Italy
# 1                1     Portugal
# 2                2           US
# 3                3           US
# 4                4           US
# 5                5        Spain
# 6                6        Italy
# 7                7       France
# 8                8      Germany
# 9                9       France
# 10              10           US
# 11              11       France
# 12              12           US
# 13              13        Italy
# 14              14           US
# 15              15      Germany
# 16              16    Argentina
# 17              17    Argentina
# 18              18        Spain
# 19              19           US
# 20              20           US
# 21              21           US
# 22              22        Italy
# 23              23           US
# 24              24        Italy
# 25              25           US
# 26              26        Italy
# 27              27        Italy
# ...

# %% [markdown]
# There's a lot of information here, but let's just use two items right now. We'll look at the number of points WineEnthusiast rated a wine and try to guess the price.

# %%
skimmed_data = data[['points', 'price']]
skimmed_data
# Out:
#         points  price
# 0           87    NaN
# 1           87   15.0
# 2           87   14.0
# 3           87   13.0
# 4           87   65.0
# 5           87   15.0
# 6           87   16.0
# 7           87   24.0
# 8           87   12.0
# 9           87   27.0
# 10          87   19.0
# 11          87   30.0
# 12          87   34.0
# 13          87    NaN
# 14          87   12.0
# 15          87   24.0
# 16          87   30.0
# 17          87   13.0
# 18          87   28.0
# 19          87   32.0
# 20          87   23.0
# 21          87   20.0
# 22          87   19.0
# 23          87   22.0
# 24          87   35.0
# 25          87   69.0
# 26          87   13.0
# 27          87   10.0
# 28          87   17.0
# 29          86   16.0
# ...        ...    ...
# 129941      90   20.0
# 129942      90   35.0
# 129943      90   29.0
# 129944      90   25.0
# 129945      90   20.0
# 129946      90   17.0
# 129947      90   20.0
# 129948      90   43.0
# 129949      90   35.0
# ...

# %% [markdown]
# There are some wines where the price is not available ('NaN'). We'll need to remove these from the data.

# %%
skimmed_data = skimmed_data[np.isfinite(skimmed_data['price'])]

# %%
plt.scatter(skimmed_data['points'], skimmed_data['price'])

# %%
from scipy.stats import binned_statistic
binned_average_price = binned_statistic(skimmed_data['points'], skimmed_data['price'], bins=20, range=(0,100)).statistic
plt.plot(np.arange(0,100,5), binned_average_price)
plt.xlabel("Points")
plt.ylabel("Average Price")

# %% [markdown]
# In general, it seems like higher points are correlated with higher price, but the relationship is not super strong. Let's try training a linear regressor using gradient descent.

# %% [markdown]
# ## Sk-learn

# %% [markdown]
# Instead of coding our own gradient descent algorithm, we'll use a package called scikit-learn. This package can do very useful things such as splitting data into training and test sets, performing gradient descent, and performing analysis.

# %% [markdown]
# Here we have sklearn use stochastic gradient descent (SGD) to solve a linear regression problem.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error

# %%
X = skimmed_data['points'].values.reshape(-1,1)
y = skimmed_data['price'].values.reshape(-1,1).ravel()
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.2)

# %%
learning_rate = 0.000000000001
n_epochs = 3
batch_size = 10000

# %%
p = [np.random.normal(), np.random.normal(), np.random.normal(), np.random.normal()]
p_gradient = [0, 0, 0, 0]
loss = 0

train_loss_history = []
test_loss_history = []
n_iterated = 0

def model(x):
    return p[0]*x**3 + p[1]*x**2 + p[2]*x + p[3]

for epoch_n in range(n_epochs):
    print("Epoch", epoch_n+1)
    for x, y in zip(X_train, y_train):
        # calculate output using model
        y_predicted = model(x)
        # calculate loss
        loss += (y_predicted - y)**2
        # find gradients
        for i in range(4):
            p_gradient[i] += 2*(y_predicted - y) * x**(3-i)
        # update parameters
        n_iterated += 1;
        if (n_iterated+1)%batch_size == 0:
            train_loss_history.append(loss / batch_size)
            y_test_predicted = [model(x) for x in X_test]
            test_loss = [(i-j)**2 for i,j in zip(y_test_predicted, y_test)]
            test_loss_history.append(sum(test_loss) / len(test_loss))
            for i in range(4):
                p[i] -= learning_rate * p_gradient[i] / batch_size
            p_gradient = [0, 0, 0, 0]
            loss = 0
# Out:
# Epoch 1
# Epoch 2
# Epoch 3

# %%
plt.scatter(X_test, y_test)
plt.scatter(X_test, y_test_predicted, color='red')

# %%
plt.plot(train_loss_history, label='train')
plt.plot(test_loss_history, color='red', label='test')
plt.yscale('log')
plt.legend()
