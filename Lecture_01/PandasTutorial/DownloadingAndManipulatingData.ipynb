# %%
# %matplotlib inline
import matplotlib
import pandas as pd
pd.set_option('display.mpl_style', 'default')
# Out:
# /Users/mattzhang/py2_kernel/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/mattzhang/py2_kernel/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
weather_2012_final = pd.read_csv('pandas-cookbook/data/weather_2012.csv', index_col='Date/Time')

# %%
weather_2012_final[:5]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %%
weather_2012_final.describe()
# Out:
#           Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count  8784.000000         8784.000000  8784.000000      8784.000000
# mean      8.798144            2.555294    67.431694        14.945469
# std      11.687883           10.883072    16.918881         8.688696
# min     -23.300000          -28.500000    18.000000         0.000000
# 25%       0.100000           -5.900000    56.000000         9.000000
# 50%       9.300000            3.300000    68.000000        13.000000
# 75%      18.800000           11.800000    81.000000        20.000000
# max      33.000000           24.400000   100.000000        83.000000
#
#        Visibility (km)  Stn Press (kPa)
# count      8784.000000      8784.000000
# mean         27.664447       101.051623
# std          12.622688         0.844005
# min           0.200000        97.520000
# 25%          24.100000       100.560000
# 50%          25.000000       101.070000
# 75%          25.000000       101.590000
# ...

# %%
weather_2012_final['Temp (C)'].plot(figsize=(15,5))

# %% [markdown]
# The URL access method changed and I don't want to deal with it. Just read the notebook at http://nbviewer.jupyter.org/github/jvns/pandas-cookbook/blob/v0.1/cookbook/Chapter%205%20-%20Combining%20dataframes%20and%20scraping%20Canadian%20weather%20data.ipynb.

# %%
url_template = "http://climate.weather.gc.ca/climateData/bulkdata_e.html?format=csv&stationID=5415&Year={year}&Month={month}&timeframe=1&submit=Download+Data"

# %%
url = url_template.format(month=3, year=2012)
weather_mar2010 = pd.read_csv(url, skiprows=16, index_col='Date/Time', parse_dates=True, encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-8a4b41242435> in <module>()
#       1 url = url_template.format(month=3, year=2012)
# ----> 2 weather_mar2010 = pd.read_csv(url, skiprows=16, index_col='Date/Time', parse_dates=True, encoding='latin1')
#
# ...

# %%
weather_mar2012 = weather_mar2012.dropna(axis=1, how='any') # drop any columns with NaN values
